# %% [markdown]
# # Day 1 - Session 1: Introduction to R and R Basics
# **Duration: ~1 hour**
#
# ## Learning Objectives
# - Understand what R is and why it's useful for research
# - Learn basic R syntax and operations
# - Master fundamental data types
# - Work with basic data structures

# %% [markdown]
# ## 1. What is R?
#
# R is a free, open-source programming language specifically designed for:
# - Statistical computing and data analysis
# - Data visualization
# - Reproducible research
#
# **Why R for PhD students?**
# - Free and open-source
# - Extensive statistical capabilities
# - Strong community support
# - Thousands of packages for specialized analyses
# - Publication-quality graphics

# %% [markdown]
# ## 2. Basic R Syntax and Operations
#
# ### 2.1 R as a Calculator

# %%
# Basic arithmetic operations
5 + 3      # Addition
10 - 4     # Subtraction
6 * 7      # Multiplication
20 / 4     # Division
2^3        # Exponentiation
17 %% 5    # Modulo (remainder)
17 %/% 5   # Integer division

# %% [markdown]
# ### 2.2 Creating Variables
#
# Variables store values for later use. Use `<-` or `=` for assignment.

# %%
# Creating variables
x <- 10
y <- 5
z <- x + y

# Display the result
print(z)
z  # Simply typing the variable name also displays it

# %%
# Variable names rules:
# - Must start with a letter
# - Can contain letters, numbers, dots, and underscores
# - Case sensitive

my_variable <- 100
MyVariable <- 200
my.variable <- 300

print(my_variable)  # Different from MyVariable

# %% [markdown]
# ### 2.3 Comments
#
# Use `#` to add comments. Everything after `#` on a line is ignored by R.

# %%
# This is a comment
sample_size <- 30  # This calculates the sample size

# %% [markdown]
# ## 3. Data Types in R
#
# R has several basic data types:
# - **numeric**: Numbers (integers and decimals)
# - **character**: Text strings
# - **logical**: TRUE or FALSE
# - **integer**: Whole numbers
# - **complex**: Complex numbers

# %%
# Numeric
height <- 175.5
class(height)

# Character
name <- "Alice"
class(name)

# Logical
is_student <- TRUE
class(is_student)

# Integer (use L suffix)
count <- 42L
class(count)

# %%
# Check the type of any object
typeof(height)
typeof(name)
typeof(is_student)

# %% [markdown]
# ### Type Conversion

# %%
# Converting between types
x <- "123"
print(class(x))

x_numeric <- as.numeric(x)
print(class(x_numeric))

# Converting numeric to character
y <- 456
y_char <- as.character(y)
print(class(y_char))

# %% [markdown]
# ## 4. Data Structures
#
# ### 4.1 Vectors
#
# Vectors are the most basic data structure in R. They contain elements of the same type.

# %%
# Creating vectors with c() function
ages <- c(25, 32, 28, 45, 38)
names <- c("Alice", "Bob", "Charlie", "Diana", "Eve")
is_phd <- c(TRUE, TRUE, FALSE, TRUE, FALSE)

print(ages)
print(names)

# %%
# Sequences
seq1 <- 1:10          # Simple sequence
seq2 <- seq(0, 100, by=10)  # Sequence with step
seq3 <- seq(0, 1, length.out=11)  # Sequence with length

print(seq1)
print(seq2)
print(seq3)

# %%
# Repetition
rep1 <- rep(5, times=10)  # Repeat 5 ten times
rep2 <- rep(c(1,2,3), times=3)  # Repeat vector three times
rep3 <- rep(c(1,2,3), each=3)   # Repeat each element three times

print(rep1)
print(rep2)
print(rep3)

# %% [markdown]
# ### 4.2 Vector Operations

# %%
# Arithmetic operations on vectors
v1 <- c(1, 2, 3, 4, 5)
v2 <- c(10, 20, 30, 40, 50)

v1 + v2  # Element-wise addition
v1 * v2  # Element-wise multiplication
v2 / v1  # Element-wise division

# %%
# Operations with scalars (recycling)
v1 * 10  # Multiply each element by 10
v1 + 5   # Add 5 to each element

# %%
# Useful vector functions
numbers <- c(12, 45, 23, 67, 34, 89, 21)

length(numbers)  # Number of elements
sum(numbers)     # Sum of all elements
mean(numbers)    # Average
median(numbers)  # Median
min(numbers)     # Minimum value
max(numbers)     # Maximum value
sd(numbers)      # Standard deviation
var(numbers)     # Variance

# %% [markdown]
# ### 4.3 Indexing Vectors
#
# Accessing specific elements in a vector (R uses 1-based indexing!)

# %%
fruits <- c("apple", "banana", "cherry", "date", "elderberry")

# Access by position
fruits[1]        # First element
fruits[3]        # Third element
fruits[c(1,3,5)] # Multiple elements
fruits[2:4]      # Range of elements

# %%
# Negative indexing (exclude elements)
fruits[-1]       # All except first
fruits[-c(2,4)]  # Exclude second and fourth

# %%
# Logical indexing
ages <- c(25, 32, 28, 45, 38)
ages > 30        # Returns logical vector
ages[ages > 30]  # Filter values greater than 30

# %% [markdown]
# ### 4.4 Named Vectors

# %%
# Vectors can have names
person_ages <- c(Alice=25, Bob=32, Charlie=28)
print(person_ages)

# Access by name
person_ages["Alice"]

# Get names
names(person_ages)

# %% [markdown]
# ### 4.5 Matrices
#
# Matrices are 2-dimensional arrays with elements of the same type.

# %%
# Creating matrices
mat1 <- matrix(1:12, nrow=3, ncol=4)
print(mat1)

# Fill by rows instead of columns
mat2 <- matrix(1:12, nrow=3, ncol=4, byrow=TRUE)
print(mat2)

# %%
# Matrix indexing: [row, column]
mat1[2, 3]      # Element in row 2, column 3
mat1[1, ]       # Entire first row
mat1[, 2]       # Entire second column
mat1[1:2, 2:3]  # Submatrix

# %%
# Matrix dimensions
dim(mat1)    # Dimensions
nrow(mat1)   # Number of rows
ncol(mat1)   # Number of columns

# %% [markdown]
# ### 4.6 Lists
#
# Lists can contain elements of different types.

# %%
# Creating a list
my_list <- list(
  name = "John Doe",
  age = 35,
  scores = c(85, 92, 78),
  is_phd = TRUE
)

print(my_list)

# %%
# Accessing list elements
my_list$name        # By name using $
my_list[["age"]]    # By name using [[]]
my_list[[2]]        # By position
my_list[1]          # Returns a list with one element

# %% [markdown]
# ### 4.7 Data Frames
#
# Data frames are the most important data structure for data analysis - they're like spreadsheets!

# %%
# Creating a data frame
df <- data.frame(
  name = c("Alice", "Bob", "Charlie", "Diana"),
  age = c(25, 32, 28, 45),
  department = c("Biology", "Chemistry", "Physics", "Biology"),
  is_phd = c(TRUE, TRUE, FALSE, TRUE)
)

print(df)

# %%
# Exploring data frames
head(df)      # First few rows
str(df)       # Structure of the data frame
summary(df)   # Summary statistics
dim(df)       # Dimensions
names(df)     # Column names

# %%
# Accessing columns
df$name           # Using $
df[["age"]]       # Using [[]]
df[, "department"] # Using [,]
df[, 2]           # By column number

# %%
# Accessing rows
df[1, ]         # First row
df[c(1,3), ]    # First and third rows

# %%
# Filtering rows
df[df$age > 30, ]              # Rows where age > 30
df[df$department == "Biology", ]  # Rows from Biology department

# %% [markdown]
# ## 6. Practice Exercises
#
# ### Exercise 1: Basic Operations
# Calculate the BMI for someone with weight 75 kg and height 1.80 m.
# Formula: BMI = weight / height²

# %% [markdown]
# ## 5. R Packages and Libraries
#
# ### What are R Packages?
#
# **R packages** are collections of functions, data, and documentation that extend R's capabilities. Think of them as apps for R:
# - **Base R** provides fundamental functionality
# - **Packages** add specialized tools for specific tasks
#
# **Why use packages?**
# - 🔬 Specialized statistical methods (e.g., survival analysis, genomics)
# - 📊 Advanced visualization (e.g., ggplot2, plotly)
# - 📁 Import data from various formats (e.g., Excel, databases)
# - 🧬 Bioinformatics tools (e.g., Bioconductor packages)
# - 🤖 Machine learning algorithms

# %% [markdown]
# ### Where to Find R Packages?
#
# **1. CRAN (Comprehensive R Archive Network)**
# - Official repository with over 18,000 packages
# - All packages tested and documented
# - Website: https://cran.r-project.org/
#
# **2. Bioconductor**
# - Specialized for bioinformatics and genomics
# - Over 2,000 packages for biological data analysis
# - Website: https://bioconductor.org/
#
# **3. GitHub**
# - Development versions and specialized packages
# - Not always as stable as CRAN packages
#
# **4. R-Forge, Neuroconductor, etc.**
# - Other specialized repositories

# %% [markdown]
# ### Installing Packages
#
# Use `install.packages()` to install from CRAN. **You only need to install a package once!**

# %%
# Install a single package
install.packages("ggplot2")

# Install multiple packages at once
install.packages(c("dplyr", "tidyr", "readr"))

# Install from a specific CRAN mirror
install.packages("package_name", repos = "https://cran.rstudio.com/")

# Note: During installation, you may be asked to choose a CRAN mirror
# Select one close to your location for faster downloads

# %% [markdown]
# ### Loading Packages
#
# After installation, use `library()` or `require()` to load a package. **You must load packages in each R session!**

# %%
# Load a package (preferred method)
library(ggplot2)

# Alternative: require() - returns TRUE/FALSE
if(require(dplyr)) {
  print("dplyr loaded successfully!")
} else {
  print("dplyr not installed")
}

# Load multiple packages
library(dplyr)
library(tidyr)
library(readr)

# %% [markdown]
# ### Useful Package Commands

# %%
# See all installed packages
installed.packages()

# See loaded packages in current session
search()

# Get help for a package
help(package = "ggplot2")

# Update all packages
update.packages()

# Update a specific package
update.packages("ggplot2")

# Remove a package
remove.packages("package_name")

# Check package version
packageVersion("ggplot2")

# %% [markdown]
# ### Popular R Packages for Research
#
# **Data Manipulation:**
# - `dplyr` - Data manipulation (you'll learn this later!)
# - `tidyr` - Data tidying and reshaping
# - `data.table` - Fast data manipulation for large datasets
#
# **Visualization:**
# - `ggplot2` - Publication-quality graphics (you'll learn this!)
# - `plotly` - Interactive plots
# - `pheatmap` - Heatmaps for biology
#
# **Data Import:**
# - `readxl` - Read Excel files
# - `readr` - Fast reading of text files
# - `haven` - Read SPSS, Stata, SAS files
#
# **Bioinformatics:**
# - `DESeq2` - Differential gene expression
# - `edgeR` - RNA-seq analysis
# - `limma` - Microarray analysis
# - `Seurat` - Single-cell RNA-seq
#
# **Statistics:**
# - `survival` - Survival analysis
# - `lme4` - Mixed-effects models
# - `caret` - Machine learning
#
# **Reporting:**
# - `rmarkdown` - Create reports, presentations
# - `knitr` - Dynamic document generation

# %% [markdown]
# ### The Tidyverse
#
# **Tidyverse** is a collection of R packages that work together seamlessly:
#
# ```r
# install.packages("tidyverse")
# ```
#
# This single command installs 8 core packages:
# - `ggplot2` - visualization
# - `dplyr` - data manipulation
# - `tidyr` - data tidying
# - `readr` - data import
# - `purrr` - functional programming
# - `tibble` - modern data frames
# - `stringr` - string manipulation
# - `forcats` - factor handling
#
# **Loading tidyverse:**
# ```r
# library(tidyverse)  # Loads all core packages at once
# ```

# %% [markdown]
# ### Practical Example: Using a Package

# %%
# Example: Using the 'praise' package for encouragement!

# Step 1: Install (uncomment to run - only needed once)
# install.packages("praise")

# Step 2: Load the package
library(praise)

# Step 3: Use functions from the package
praise()
praise()
praise()

# Different templates
praise("${EXCLAMATION}! Your R code is ${adjective}!")

# %% [markdown]
# ### 💡 Key Takeaways
#
# **Remember:**
# - 📦 **Install once:** `install.packages("package_name")`
# - 📚 **Load every session:** `library(package_name)`
# - 🔍 **Find packages:** CRAN, Bioconductor, GitHub
# - 📖 **Get help:** `help(package = "package_name")`
# - 🔄 **Keep updated:** `update.packages()`
#
# **Common mistake:**
# ```r
# # ❌ Forgot to load package
# ggplot(data, aes(x, y))  # Error: could not find function "ggplot"
#
# # ✅ Load package first
# library(ggplot2)
# ggplot(data, aes(x, y))  # Works!
# ```

# %%
# Your code here

# %% [markdown]
# ### Exercise 2: Vectors
# Create a vector of temperatures in Celsius: 0, 10, 20, 30, 40
# Convert them to Fahrenheit using the formula: F = (C * 9/5) + 32

# %%
# Your code here

# %% [markdown]
# ### Exercise 3: Data Frame
# Create a data frame with information about 5 experiments:
# - experiment_id: 1 to 5
# - temperature: 20, 25, 30, 35, 40
# - success: TRUE, TRUE, FALSE, TRUE, FALSE
#
# Then filter to show only successful experiments.

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# In this session, you learned:
# - ✅ Basic R syntax and operations
# - ✅ Fundamental data types (numeric, character, logical)
# - ✅ Data structures (vectors, matrices, lists, data frames)
# - ✅ How to index and subset data
# - ✅ Basic functions for data exploration
#
# **Next session**: We'll learn more about data manipulation and reading/writing data files!

# %%
sessionInfo()

# %% [markdown]
# ## Session Info
#
# It's good practice to record your R session information at the end of your analysis. This helps with reproducibility by documenting:
# - R version
# - Operating system
# - Loaded packages and their versions
# - Other system details
